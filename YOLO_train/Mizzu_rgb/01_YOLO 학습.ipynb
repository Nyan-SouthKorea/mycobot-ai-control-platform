# %%
from ultralytics import YOLO

# 1) 프리트레인 모델 1개 로드 (nano 예시)
model = YOLO("yolo26m.pt")

# 2) 학습 (하드코딩)
model.train(
    data='./data.yaml',
    epochs=100,
    imgsz=640,
    batch=16,
    device=0,   # GPU 0, CPU면 "cpu"
)
# Out:
# WARNING Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\AI\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.8  Python-3.10.19 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
import os
os.listdir('./')
# Out:
# ['00_데이터 전처리.ipynb',
#  '01_YOLO 학습.ipynb',
#  'data.yaml',
#  'dataset',
#  'runs',
#  'yolo26m.pt',
#  'yolo26n.pt']

# %%
from ultralytics import YOLO

model = YOLO("./runs/detect/myzzu_train/weights/best.pt")  # 너 best.pt 경로
model.predict(source=0, show=True, conf=0.8)                 # 웹캠(0) 바로 띄우고 추론
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 2 blocks, 12.7ms
# 0: 480x640 2 blocks, 12.8ms
# 0: 480x640 2 blocks, 12.6ms
# 0: 480x640 1 block, 12.5ms
# 0: 480x640 2 blocks, 12.9ms
# 0: 480x640 2 blocks, 13.3ms
# 0: 480x640 1 block, 13.6ms
# 0: 480x640 2 blocks, 12.7ms
# 0: 480x640 2 blocks, 13.5ms
# 0: 480x640 1 block, 12.3ms
# 0: 480x640 1 block, 12.0ms
# 0: 480x640 1 block, 11.5ms
# ...
